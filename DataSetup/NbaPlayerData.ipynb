# %%
import pandas as pd

# %%
pd.read_csv("nba_1415.csv")
# Out:
#               PLAYER TEAM  AGE  GP  W  L   MIN   PTS  FGM   FGA  ...   REB  \
# 0       Aaron Brooks  CHI   30  12  6  6  11.0   4.5  1.8   5.1  ...   1.5
# 1         Al Horford  ATL   29  16  8  8  32.6  14.4  6.7  13.2  ...   8.6
# 2    Al-Farouq Aminu  DAL   24   5  1  4  30.0  11.2  3.4   6.2  ...   7.2
# 3      Alan Anderson  BKN   32   6  2  4  23.6  11.0  4.2   6.8  ...   3.5
# 4      Alexis Ajinca  NOP   27   3  0  3   3.5   2.7  1.3   1.3  ...   0.3
# ..               ...  ...  ...  .. .. ..   ...   ...  ...   ...  ...   ...
# 203   Tyson Chandler  DAL   32   5  1  4  32.1  10.2  3.8   5.8  ...  10.8
# 204     Vince Carter  MEM   38  11  6  5  17.8   6.3  2.5   6.1  ...   4.3
# 205       Will Bynum  WAS   32   3  2  1  10.5   6.3  2.3   4.7  ...   1.0
# 206    Zach Randolph  MEM   33  11  6  5  34.7  15.6  6.5  15.3  ...   8.5
# 207    Zaza Pachulia  MIL   31   6  2  4  21.4   6.7  2.7   6.7  ...   6.7
#
#      AST  TOV  STL  BLK   PF    FP  DD2  TD3  +/-
# ...

# %%
pd.read_csv("nba_1516.csv")
# Out:
#               PLAYER TEAM  AGE  GP  W  L   MIN   PTS  FGM   FGA  ...  REB  \
# 0     Aaron Harrison  CHA   21   2  1  1   3.7   0.0  0.0   0.0  ...  0.5
# 1         Al Horford  ATL   30  10  4  6  32.7  13.4  5.4  11.6  ...  6.5
# 2       Al Jefferson  CHA   31   7  3  4  24.1  13.3  6.0  11.9  ...  6.1
# 3    Al-Farouq Aminu  POR   25  11  5  6  33.8  14.6  5.1  11.6  ...  8.6
# 4       Allen Crabbe  POR   24  11  5  6  27.5   9.5  3.5   6.6  ...  2.9
# ..               ...  ...  ...  .. .. ..   ...   ...  ...   ...  ...  ...
# 210   Wesley Johnson  LAC   28   6  2  4  12.8   2.7  0.8   2.3  ...  3.0
# 211  Wesley Matthews  DAL   29   5  1  4  34.7  13.0  4.0  12.0  ...  3.6
# 212   Xavier Munford  MEM   24   4  0  4  22.3   4.8  2.3   7.0  ...  2.3
# 213    Zach Randolph  MEM   34   4  0  4  29.9  13.0  5.8  15.5  ...  8.8
# 214    Zaza Pachulia  DAL   32   5  1  4  22.4   6.6  1.8   4.8  ...  5.4
#
#      AST  TOV  STL  BLK   PF    FP  DD2  TD3   +/-
# ...
